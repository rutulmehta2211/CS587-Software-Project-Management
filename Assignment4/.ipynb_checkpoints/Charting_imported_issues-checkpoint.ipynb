# %% [markdown]
# # Plot the Graph for the total number of issues with different labels created and closed on every date on GitHub for SPM587SP21 issues project

# %% [markdown]
# ### Example of Issue Form Filled out

# %% [raw]
# Author: SCM587SP21
# created_at: 2021-03-03,
# labels:  Category:Bug, DetectionPhase:Field, OriginationPhase:Coding, Priority:Critical
# State: closed,
# issue_number: 002,
# closed_at: 2021-03-05

# %% [markdown]
# ### Data Set File:  SPM587SP21issues.json

# %%
import os

import warnings
warnings.filterwarnings('ignore')

import pandas as pd                                    # panda's nickname is pd

import numpy as np                                     # numpy as np

from pandas import DataFrame, Series                   # for convenience

import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Requirement : Get the total number of issues with different labels for every date and plot them in a stacked chart

# %%
# Read the JSON file into a list of dictionaries

import json
list_of_issues_dict_data = [json.loads(line) for line in open('SPM587SP21issues.json')]

# %%
# Create the DataFrame object for the list_of_issues_dict_data object

issues_df = DataFrame(list_of_issues_dict_data)

# %%
# Sanity test: print rows in our DataFrame

issues_df
# Out:
#      issue_number  created_at   closed_at  \
# 0             322  2021-04-07  2021-04-08
# 1             320  2021-04-07  2021-04-08
# 2             317  2021-04-07  2021-04-07
# 3             314  2021-04-07  2021-04-07
# 4             312  2021-04-07  2021-04-07
# ..            ...         ...         ...
# 155             5  2021-03-03        None
# 156             4  2021-03-03        None
# 157             3  2021-03-03  2021-03-05
# 158             2  2021-03-03  2021-03-05
# 159             1  2021-03-03        None
#
#                                                 labels   State       Author
# 0    [Category:Enhancement, DetectionPhase:Testing,...  closed  MSP21SCM41J
# 1    [Category:Inquiry, DetectionPhase:Field, Origi...  closed  SSP21SCM84S
# 2    [Category:Bug, DetectionPhase:Testing, Origina...  closed  RSP21SCM47M
# 3    [Category:Enhancement, DetectionPhase:Testing,...  closed  RSP21SCM43S
# 4    [Category:Inquiry, DetectionPhase:Field, Origi...  closed  YSP21SCM14W
# ..                                                 ...     ...          ...
# 155  [Category:Enhancement, DetectionPhase:Requirem...    open   SPM587SP21
# 156  [Category:Bug, DetectionPhase:Field, Originati...    open   SPM587SP21
# 157  [Category:Inquiry, DetectionPhase:Documentatio...  closed   SPM587SP21
# 158  [Category:Enhancement, DetectionPhase:Design, ...  closed   SPM587SP21
# 159  [Category:Bug, DetectionPhase:Coding, Originat...    open   SPM587SP21
#
# [160 rows x 6 columns]

# %%
# Prepare and Clean the dataframe object

wrangled_issues_df = issues_df[['Author','State','closed_at','created_at','issue_number','labels']]
wrangled_issues_df.loc[0:len(wrangled_issues_df), 'OriginationPhase']= np.NaN
wrangled_issues_df.loc[0:len(wrangled_issues_df),'DetectionPhase']= np.NaN
wrangled_issues_df.loc[0:len(wrangled_issues_df),'Category']= np.NaN
wrangled_issues_df.loc[0:len(wrangled_issues_df),'Priority']= np.NaN
wrangled_issues_df.loc[0:len(wrangled_issues_df),'Status']= np.NaN

# %%
wrangled_issues_df
# Out:
#           Author   State   closed_at  created_at  issue_number  \
# 0    MSP21SCM41J  closed  2021-04-08  2021-04-07           322
# 1    SSP21SCM84S  closed  2021-04-08  2021-04-07           320
# 2    RSP21SCM47M  closed  2021-04-07  2021-04-07           317
# 3    RSP21SCM43S  closed  2021-04-07  2021-04-07           314
# 4    YSP21SCM14W  closed  2021-04-07  2021-04-07           312
# ..           ...     ...         ...         ...           ...
# 155   SPM587SP21    open        None  2021-03-03             5
# 156   SPM587SP21    open        None  2021-03-03             4
# 157   SPM587SP21  closed  2021-03-05  2021-03-03             3
# 158   SPM587SP21  closed  2021-03-05  2021-03-03             2
# 159   SPM587SP21    open        None  2021-03-03             1
#
#                                                 labels  OriginationPhase  \
# 0    [Category:Enhancement, DetectionPhase:Testing,...               NaN
# 1    [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# 2    [Category:Bug, DetectionPhase:Testing, Origina...               NaN
# 3    [Category:Enhancement, DetectionPhase:Testing,...               NaN
# 4    [Category:Inquiry, DetectionPhase:Field, Origi...               NaN
# ..                                                 ...               ...
# 155  [Category:Enhancement, DetectionPhase:Requirem...               NaN
# 156  [Category:Bug, DetectionPhase:Field, Originati...               NaN
# 157  [Category:Inquiry, DetectionPhase:Documentatio...               NaN
# 158  [Category:Enhancement, DetectionPhase:Design, ...               NaN
# 159  [Category:Bug, DetectionPhase:Coding, Originat...               NaN
#
#      DetectionPhase  Category  Priority  Status
# 0               NaN       NaN       NaN     NaN
# 1               NaN       NaN       NaN     NaN
# 2               NaN       NaN       NaN     NaN
# 3               NaN       NaN       NaN     NaN
# 4               NaN       NaN       NaN     NaN
# ..              ...       ...       ...     ...
# 155             NaN       NaN       NaN     NaN
# 156             NaN       NaN       NaN     NaN
# 157             NaN       NaN       NaN     NaN
# 158             NaN       NaN       NaN     NaN
# 159             NaN       NaN       NaN     NaN
#
# [160 rows x 11 columns]

# %%
for i in range(0, len(wrangled_issues_df)):
    if wrangled_issues_df.iloc[i]['labels']:
        for label in wrangled_issues_df.iloc[i]['labels']:
            if len(label.split(':')) == 2:
                label_name= (label.split(':'))[0]
                label_value= (label.split(':'))[1]
                wrangled_issues_df.loc[i, label_name]=label_value

# %%
wrangled_issues_df
# Out:
#           Author   State   closed_at  created_at  issue_number  \
# 0    MSP21SCM41J  closed  2021-04-08  2021-04-07           322
# 1    SSP21SCM84S  closed  2021-04-08  2021-04-07           320
# 2    RSP21SCM47M  closed  2021-04-07  2021-04-07           317
# 3    RSP21SCM43S  closed  2021-04-07  2021-04-07           314
# 4    YSP21SCM14W  closed  2021-04-07  2021-04-07           312
# ..           ...     ...         ...         ...           ...
# 155   SPM587SP21    open        None  2021-03-03             5
# 156   SPM587SP21    open        None  2021-03-03             4
# 157   SPM587SP21  closed  2021-03-05  2021-03-03             3
# 158   SPM587SP21  closed  2021-03-05  2021-03-03             2
# 159   SPM587SP21    open        None  2021-03-03             1
#
#                                                 labels OriginationPhase  \
# 0    [Category:Enhancement, DetectionPhase:Testing,...     Requirements
# 1    [Category:Inquiry, DetectionPhase:Field, Origi...           Coding
# 2    [Category:Bug, DetectionPhase:Testing, Origina...     Requirements
# 3    [Category:Enhancement, DetectionPhase:Testing,...           Design
# 4    [Category:Inquiry, DetectionPhase:Field, Origi...    Documentation
# ..                                                 ...              ...
# 155  [Category:Enhancement, DetectionPhase:Requirem...     Requirements
# 156  [Category:Bug, DetectionPhase:Field, Originati...            Field
# 157  [Category:Inquiry, DetectionPhase:Documentatio...    Documentation
# 158  [Category:Enhancement, DetectionPhase:Design, ...           Design
# 159  [Category:Bug, DetectionPhase:Coding, Originat...           Coding
#
#     DetectionPhase     Category  Priority         Status
# 0          Testing  Enhancement     Major      Completed
# 1            Field      Inquiry       Low     inProgress
# 2          Testing          Bug     Major      Completed
# 3          Testing  Enhancement  Critical       Approved
# 4            Field      Inquiry      High     inProgress
# ..             ...          ...       ...            ...
# 155   Requirements  Enhancement    Medium       Rejected
# 156          Field          Bug     Major  pendingReview
# 157  Documentation      Inquiry       Low     inProgress
# 158         Design  Enhancement      High      Completed
# 159         Coding          Bug  Critical       Approved
#
# [160 rows x 11 columns]

# %%
# Plot in Bar Chart the total number of issues created every day for every Detaction Phase

LabelsReviewedByDate = wrangled_issues_df.groupby(['created_at','DetectionPhase']).created_at.count()

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['red', 'yellow', 'blue', 'purple', 'green'], grid=False)

# %%
# Plot in Bar Chart the total number of issues created for every Phase based on their priorites

LabelsReviewedByDate = wrangled_issues_df.groupby(['Priority','DetectionPhase']).created_at.count()

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue','yellow', 'purple', 'red', 'green'], grid=False)

# %%
# Plot in Bar Chart the total number of issues closed every day for every Category

LabelsReviewedByDate = wrangled_issues_df.groupby(['closed_at','Category']).closed_at.count()

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue', 'purple', 'red', 'yellow', 'green'], grid=False)

# %% [markdown]
# #  Requirement #1: Plot in Bar Chart the total number of issues closed every day for every Origination Phase

# %%
# Requirement #1: Add your code here

LabelsReviewedByDate = wrangled_issues_df.groupby(['closed_at','OriginationPhase']).closed_at.count()

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue','yellow', 'purple', 'cyan', 'red', 'green'], grid=False)

# %% [markdown]
# #  Requirement #2: # Plot in Bar Chart the total number of issues created for every Phase based on their Status

# %%
# Requirement #2: Add your code here

LabelsReviewedByDate = wrangled_issues_df.groupby(['Status','DetectionPhase']).created_at.count()

dateLabelsFig = LabelsReviewedByDate.unstack().plot(kind='bar',stacked=True,  color=['blue','yellow', 'purple', 'magenta', 'red', 'green'], grid=False)
